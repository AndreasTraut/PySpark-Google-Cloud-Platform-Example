# %%
# !pip install --upgrade  pandas
# !pip install --upgrade  pandas_gbq
# !pip install --upgrade  pyspark
# Out:
# Requirement already up-to-date: pandas in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.25.3)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (1.16.4)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas) (2019.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Requirement already up-to-date: pandas_gbq in /srv/conda/envs/notebook/lib/python3.7/site-packages (0.11.0)
# Requirement already satisfied, skipping upgrade: pydata-google-auth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_gbq) (0.1.3)
# Requirement already satisfied, skipping upgrade: google-auth in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_gbq) (1.6.3)
# Requirement already satisfied, skipping upgrade: setuptools in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_gbq) (41.0.1)
# Requirement already satisfied, skipping upgrade: google-cloud-bigquery>=1.9.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_gbq) (1.21.0)
# Requirement already satisfied, skipping upgrade: pandas>=0.19.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_gbq) (0.25.3)
# Requirement already satisfied, skipping upgrade: google-auth-oauthlib in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas_gbq) (0.4.1)
# Requirement already satisfied, skipping upgrade: six>=1.9.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-auth->pandas_gbq) (1.12.0)
# Requirement already satisfied, skipping upgrade: pyasn1-modules>=0.2.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-auth->pandas_gbq) (0.2.7)
# Requirement already satisfied, skipping upgrade: rsa>=3.1.4 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-auth->pandas_gbq) (4.0)
# Requirement already satisfied, skipping upgrade: cachetools>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-auth->pandas_gbq) (3.1.1)
# Requirement already satisfied, skipping upgrade: google-cloud-core<2.0dev,>=1.0.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-cloud-bigquery>=1.9.0->pandas_gbq) (1.0.3)
# Requirement already satisfied, skipping upgrade: google-resumable-media!=0.4.0,<0.5.0dev,>=0.3.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-cloud-bigquery>=1.9.0->pandas_gbq) (0.4.1)
# Requirement already satisfied, skipping upgrade: protobuf>=3.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-cloud-bigquery>=1.9.0->pandas_gbq) (3.8.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.13.3 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.19.0->pandas_gbq) (1.16.4)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.19.0->pandas_gbq) (2019.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.6.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pandas>=0.19.0->pandas_gbq) (2.8.0)
# Requirement already satisfied, skipping upgrade: requests-oauthlib>=0.7.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-auth-oauthlib->pandas_gbq) (1.2.0)
# Requirement already satisfied, skipping upgrade: pyasn1<0.5.0,>=0.4.6 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth->pandas_gbq) (0.4.7)
# Requirement already satisfied, skipping upgrade: google-api-core<2.0.0dev,>=1.14.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery>=1.9.0->pandas_gbq) (1.14.3)
# Requirement already satisfied, skipping upgrade: requests>=2.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas_gbq) (2.22.0)
# Requirement already satisfied, skipping upgrade: oauthlib>=3.0.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas_gbq) (3.0.1)
# Requirement already satisfied, skipping upgrade: googleapis-common-protos<2.0dev,>=1.6.0 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from google-api-core<2.0.0dev,>=1.14.0->google-cloud-core<2.0dev,>=1.0.3->google-cloud-bigquery>=1.9.0->pandas_gbq) (1.6.0)
# Requirement already satisfied, skipping upgrade: chardet<3.1.0,>=3.0.2 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas_gbq) (3.0.4)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas_gbq) (2019.6.16)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas_gbq) (1.25.3)
# Requirement already satisfied, skipping upgrade: idna<2.9,>=2.5 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib->pandas_gbq) (2.8)
# Requirement already up-to-date: pyspark in /srv/conda/envs/notebook/lib/python3.7/site-packages (2.4.4)
# Requirement already satisfied, skipping upgrade: py4j==0.10.7 in /srv/conda/envs/notebook/lib/python3.7/site-packages (from pyspark) (0.10.7)

# %%
#GCP
#Projektname
#My Project 47256
#Projekt-ID
#analog-marking-258015 

from pandas.io import gbq
project_id = "analog-marking-258015"
query = """
    SELECT * 
    FROM `bigquery-public-data.samples.natality` 
    limit 10000
"""
births = gbq.read_gbq(query=query, dialect ='standard', project_id=project_id)
births.head()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=TfwCGQkgDxyr4i9Xp623gnw9OaOlzA&prompt=consent&access_type=offline
# Enter the authorization code:  4/swE4ZbS0Ke1W2LunmKtH9Dzj_xs_dlwjj8mnd8HlusbfcWcJN8nCrQQ
#    source_year  year  month  day  wday state  is_male  child_race  \
# 0         2005  2005      6  NaN   1.0  None     True         NaN
# 1         2005  2005     11  NaN   2.0  None    False         NaN
# 2         2005  2005      5  NaN   2.0  None     True         NaN
# 3         2005  2005      2  NaN   3.0  None     True         NaN
# 4         2005  2005      3  NaN   7.0  None    False         NaN
#
#    weight_pounds  plurality  ...  alcohol_use  drinks_per_week  \
# 0      10.061898        1.0  ...        False              NaN
# 1       7.438397        1.0  ...         None              NaN
# 2       7.561856        1.0  ...        False              NaN
# 3       7.903572        1.0  ...        False              NaN
# 4       6.437498        1.0  ...         None              NaN
#
#   weight_gain_pounds  born_alive_alive  born_alive_dead  born_dead ever_born  \
# 0               32.0               7.0              0.0        1.0         8
# 1               99.0               8.0              0.0        0.0         9
# 2               35.0               8.0              0.0        0.0         9
# 3               26.0               9.0              0.0        6.0        10
# 4               99.0               7.0              1.0        3.0         9
#
#   father_race father_age record_weight
# 0        68.0         37             1
# 1        68.0         51             1
# 2        68.0         42             1
# 3        78.0         43             1
# 4         4.0         36             1
#
# [5 rows x 31 columns]

# %%
births[['weight_pounds', 'mother_age']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f90a2b3fb38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f90a2b2bcf8>]],
#       dtype=object)
